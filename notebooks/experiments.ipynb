# %%
# %pylab inline
import glob
import os

from plot_graphs import plot_one, plot_average, plot_folder
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
logdir = '/u/noukhovm/ecn/logs/'

# %%
logfile = 'self-opputilA_260773_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm A')
logfile = 'self-opputilB_260782_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm B')
logfile = 'self-opputilboth_260775_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm Both')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4e1c3025d708> in <module>()
#       1 logfile = 'self-opputilA_260773_20181026.log'
# ----> 2 plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm A')
#       3 logfile = 'self-opputilB_260782_20181026.log'
#       4 plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm B')
#       5 logfile = 'self-opputilboth_260775_20181026.log'
#
# NameError: name 'plot_reward' is not defined

# %%
folder = 'self-both'
plot_folder(os.path.join(logdir, folder), show_both=False)
# Out:
# /u/noukhovm/ecn/logs/self-both/self-both_260784_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/_260784_20181026.log", "model_file": "model_saves/_260784_20181026.dat"}
# /u/noukhovm/ecn/logs/self-both/self-both_260785_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/_260785_20181026.log", "model_file": "model_saves/_260785_20181026.dat"}
# /u/noukhovm/ecn/logs/self-both/self-both_260787_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/_260787_20181026.log", "model_file": "model_saves/_260787_20181026.dat"}
# /u/noukhovm/ecn/logs/self-both/self-both_260786_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/_260786_20181026.log", "model_file": "model_saves/_260786_20181026.dat"}

# %%
# Out:
# /u/noukhovm/ecn/logs/self-opputilboth_260775_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/self-opputilboth_260775_20181026.log", "model_file": "model_saves/self-opputilboth_260775_20181026.dat"}
#
# epoch[0] 0 epochs[-1] 163800
