# %%
# %pylab inline
import os

from plot_graphs import plot_reward
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
logdir = '/u/noukhovm/ecn/logs'

# %%
logfile = 'self-opputilA_260773_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm A')
logfile = 'self-opputilB_260782_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm B')
logfile = 'self-opputilboth_260775_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm Both')
# Out:
# /u/noukhovm/ecn/logs/self-opputilA_260773_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/self-opputilA_260773_20181026.log", "model_file": "model_saves/self-opputilA_260773_20181026.dat"}
#
# epoch[0] 0 epochs[-1] 96400
# /u/noukhovm/ecn/logs/self-opputilB_260782_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/self-opputilB_260782_20181026.log", "model_file": "model_saves/self-opputilB_260782_20181026.dat"}
#
# epoch[0] 0 epochs[-1] 140000
# ...

# %%
logfile = 'self-opputilA_260773_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm A')
logfile = 'self-opputilB_260782_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm B')
logfile = 'self-opputilboth_260775_20181026.log'
plot_reward(os.path.join(logdir, logfile), show_train=False, show_both=False, title='Force Comm Both')
# Out:
# /u/noukhovm/ecn/logs/self-opputilB_260782_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/self-opputilB_260782_20181026.log", "model_file": "model_saves/self-opputilB_260782_20181026.dat"}
#
# epoch[0] 0 epochs[-1] 140000

# %%
# Out:
# /u/noukhovm/ecn/logs/self-opputilboth_260775_20181026.log meta: {"seed": null, "test_seed": 123, "batch_size": 128, "episodes": 500000, "term_entropy_reg": 0.05, "utterance_entropy_reg": 0.0001, "proposal_entropy_reg": 0.005, "render_every_episode": 200, "save_every_seconds": 360, "testing": false, "no_load": false, "no_save": false, "log_file": "logs/self-opputilboth_260775_20181026.log", "model_file": "model_saves/self-opputilboth_260775_20181026.dat"}
#
# epoch[0] 0 epochs[-1] 163800
